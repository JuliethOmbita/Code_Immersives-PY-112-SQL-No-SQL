# %% [markdown]
# Longest list of composite numbers from 1000,3000
# Example: for numbers between 10 and 20 the output will be [14,15,16]

# %%
num = 10
num1 = 20

count = 0
comp_list = []
numbers = []
# print (len (range(num, num1+1)))
for i in range(num, num1+1):
    # print (i)
    for y in range(2, i+1):
        # print (f'ffff {y}')
        if(i % y == 0):
            # print (i,y)
            count += 1
            numbers.append(y)
        line = [i, count, numbers] 
        # print (line)

print (f'The longest list is {line[-1]}')

# %%
# step 1 - List numbers and classify as primer or not (Composite)
# step 2 - 
# step 3 - Compare the lengh the lsat set of composites before I reset it. 


def is_prime(num):
    prime = False
    if num > 1:
        prime = True
        for i in range (2, num):
            if num % i == 0:
                prime = False
                break
    return prime

composites = []
longest_comp = []
for j in range(20):
    if is_prime(j):
        #reset
        if len(composites) >= len(longest_comp):
            longest_comp = composites
        print (f'Reset a prime was found {j}')
        composites = []
    else:
        composites.append(j)
        print(composites)
print (longest_comp)

# %%
# step 4 - Run algorithm against the larger number set
def is_prime(num):
    prime = False
    if num > 1:
        prime = True
        for i in range(2,num):
            if num % i == 0:
                prime = False
                break
    return prime

composites = []
longest_comp = []
for j in range(1000,3001):
    if is_prime(j):
        # reset
        if len(composites) >= len(longest_comp):
            longest_comp = composites
        print(f'Reset a prime was found {j}')
        composites = []
    else:
        composites.append(j)
        print(composites)
print('*'*35)
print(f'The length of the longest list of composites between 1000 and 3000 is {len(longest_comp)}')
print(longest_comp)
# Out:
# [1000]
# [1000, 1001]
# [1000, 1001, 1002]
# [1000, 1001, 1002, 1003]
# [1000, 1001, 1002, 1003, 1004]
# [1000, 1001, 1002, 1003, 1004, 1005]
# [1000, 1001, 1002, 1003, 1004, 1005, 1006]
# [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007]
# [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008]
# Reset a prime was found 1009
# [1010]
# [1010, 1011]
# [1010, 1011, 1012]
# Reset a prime was found 1013
# [1014]
# [1014, 1015]
# [1014, 1015, 1016]
# [1014, 1015, 1016, 1017]
# [1014, 1015, 1016, 1017, 1018]
# Reset a prime was found 1019
# [1020]
# Reset a prime was found 1021
# [1022]
# [1022, 1023]
# [1022, 1023, 1024]
# [1022, 1023, 1024, 1025]
# [1022, 1023, 1024, 1025, 1026]
# [1022, 1023, 1024, 1025, 1026, 1027]
# [1022, 1023, 1024, 1025, 1026, 1027, 1028]
# [1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029]
# [1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030]
# Reset a prime was found 1031
# [1032]
# Reset a prime was found 1033
# [1034]
# [1034, 1035]
# [1034, 1035, 1036]
# ...
