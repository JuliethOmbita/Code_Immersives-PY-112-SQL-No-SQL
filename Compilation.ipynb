# %%
# PYTHON BASIC COMMANDS

# Variables
x = 10
grades = [ 88,92,86, 89, 93]
words = 'A journey of a million miles begins with one step'
beg_val = 100
end_val = 121
colors = ['bluegreen','orange','aqua','Bluegray','oceangreen','white','Green','Skyblue']
lastNames = ['Davis','Smith','Jones']
empId = [111,222,333]
grades.sort(reverse = True)

print(type(x))
print(id(x))
print(round(x,1))
my_list2 = zip(empId, lastNames) # [(111, 'Davis'), (222, 'Smith'), (333, 'Jones')]

grades.append(90)
grades.pop()
grades.insert(0,'Orange')
grades.remove(93)
del grades[2]

#Indexing
print(grades[-2:])
print(grades[:2])
print(grades[:2] + grades[-2:])

#List comprehensive - for -
print ([grade[0], grade[1] for grade in enumerate(grades)])

print ([letter for letter in words])

ms = [i for i in x if not i.startswith('__')]
ms = [i for i in methods if 'item' in i]

print ([i for i in range(beg_val, end_val,2)])
print ([f'{i} is an odd number' for i in range(beg_val, end_val) if i % 2 == 1])

x = 'Python'
if isinstance(x,str):
    print(f'{x} is a string')

# 'xx' in a list
shd_green = [i.capitalize() for i in colors if 'green' in i.lower()]

#---------------
import random

rand_number = random.random()
x = random.randint(1,6)
picked = random.choice(grades)
random.shuffle(grades)


#---------------
import math
z = math.pow(2,3)

print(type(x))
print(math.pi)
print(math.inf)
print(-math.inf)
print(math.ceil(x))
print(math.e)
print(math.factorial(5))
print(math.floor(x))
print(math.pow(2,4))
print(math.sqrt(16))
print(math.prod([2,4,3]))  # takes a list
print(math.prod(range(5,0,-1)))
print(math.remainder(12,5))

#---------------
import datetime

now = datetime.datetime.now()
now = datetime.datetime.now().date() # just the date
hire_date = datetime.date(2017,2,10) # CONSTRUCT A VALID DATE
future_date = now + datetime.timedelta(days=2) # future_date - 2 days from now
days_employed = now - hire_date # Subtract 1 date from another
conv_days = days_employed.days # To convert the timedelta to days add the days method to the end
# now - 14 days
previous_date = now - datetime.timedelta(days = 14)
previous_date = now + datetime.timedelta(days = -14)


od = datetime.date(2021,6,10)
cd = datetime.date(2020,3,17)
diff = (od - cd).days
print(f'Rounded value is {math.floor(diff/365.25)} year(s)')

# Outputs: the first day, the last day and the number of days in the month as a list
import datetime

year = 2020
for i in range(1,13):
    first_day_of_month = datetime.date(year,i,1)
    if i == 12:
        last_day_of_month =  datetime.date(year+1,1,1) - datetime.timedelta(days = 1)
    else:
        last_day_of_month =  datetime.date(year,i+1,1) - datetime.timedelta(days = 1)

    print(first_day_of_month,last_day_of_month,(last_day_of_month - first_day_of_month).days+1)


#---------------
list_1 = ['chair','stools','dresser','picture frame']
list_2 = ['mirror','rug','tv stand','chair','dresser']

# Unduplicated list of all items in both lists (union)
union_list = list(set().union(list_1,list_2))
# Items are duplicated in each list (intersection)
intersection_list = list(set(list_1) & set(list_2))

#---------------
#Funcion
def add2(num):     # Define the function
    return num + 2  # Return a value

newNum = add2(8)  # Call the function
print(newNum)

#---------------


#---------------

# %%
import math

# standard deviation

grades = [ 88,92,86, 89, 93]

# Calculate the mean
calc_mean = sum(grades)/len(grades)
sum_squares = 0
for grade in grades:
    sum_squares += (grade-calc_mean) ** 2

grades_std = math.sqrt(sum_squares/(len(grades)-1))
print(f'The standard deviation of grades is {round(grades_std,2)}')

# %% [markdown]
# Compilation
#
# This jupeter nootebook has compilation of funtions and useful algorithms

# %%
# Print backwards

phrase = 'PYTHON'
for i in range (len(phrase)-1,-1,-1):
    print(i,phrase[i])
#-+-+-+-+-+-+-+-+-
# Odd and Even number
y = 10
x = 'Even number' if y % 2 == 0 else 'Odd number'
print(x)

#-+-+-+-+-+-+-+-+-
# Factorial Number
x = 5
# 5 4 3 2 1 
factorial = 1
for i in range(x,0,-1):
    factorial *= i
print(f'{x} factorial = {factorial}')
print(math.factorial(5))

print(math.prod(range(5,0,-1)))

#-+-+-+-+-+-+-+-+-

# Exercise
# Calculate the sum of the factors of all composite number from 100 to 200. 
def is_prime(num):
    prime = False
    if num > 1:
        prime = True
        for i in range(2,num):
            if num % i == 0:
                prime = False
                break
    return prime

for in_num in range(100,201):
    if not is_prime(in_num):
        factors_list = []
        sum_fact = 0
        for i in range(in_num+1):
            if i >1 and in_num % i == 0:
                factors_list.append(i)
                sum_fact = sum_fact + i
        print (f'The factor list of {in_num} is {factors_list}. The sum of the factors is: {sum_fact}')



#-+-+-+-+-+-+-+-+-
#Area / perimeter of a rectangle 

def calc_area_rectangle(l,w):
    return l * w

def calc_perimeter_rectangle(l,w):
    return 2*l + 2*w  # Comment 2 * ( l + w) 

l = 3
w = 5
print(f'The area of a rectangle with {l},{w} is {calc_area_rectangle(l,w)}')
print(f'The perimeter of a rectangle with {l},{w} is {calc_perimeter_rectangle(l,w)}')

#-+-+-+-+-+-+-+-+-
#Area / perimeter of a circle  
import math

def area_circle(r):
    '''
    This function calculate the area of a circle
    r is the radius
    
    Param r: is a float
    Returns: a float
    '''
    return round(math.pi * (r**2),2)

def perimeter_cicle(r):
    return round(2*math.pi*r, 2)

r = 10
print (f'The area of a circule with radius of {r} is: {area_circle(r)}')
print (f'The perimeter of a circule with radius od {r} is {perimeter_cicle(r)}')

#-+-+-+-+-+-+-+-+-
# Area of Triangle T = (height * base)/2 
# Area of Rectangle R = width * length
# Area of Cicle C = math.pi*(r**2)

measurements = [('T',(8,8)),('R',(4,6)),('C',(1)),('T',(14,6)),('R',(8,8)),('C',(5))]

for shape in measurements:
    if shape[0] == 'T': 
        print (f'The are of a triangle with (height,base) = {shape[1]}. A = {(shape[1][0] * shape[1][1])/2}')
    elif shape[0] == 'R': 
        print()
        print (f'The are of a rectangle with (width, length) = {shape[1]}. A = {shape[1][0] * shape[1][1]}')
    elif shape[0] == 'C': 
        print()
        print (f'The are of a circle with radio = {shape[1]}. A = {math.pi*(shape[1]**2)}')



#-+-+-+-+-+-+-+-+-
#Temperature conversion
def temp_conversion(conv_type,temp):
    '''
    Convert either Fahrenheit to Celsius or Celsius to Fahrenheit
    Use code below as the only valid inpt parameters for conv_type
    
    'FC' = Fahrenheit to Celsius
    'CF' = Celsius to Fahrenheit
    return either a None or the temperature
    '''
    res = None
    if conv_type == 'FC':
        res = (temp - 32) * 5/9
    elif conv_type == 'CF':
        res = (temp * 9/5) + 32
    else:
        print(f'{conv_type} is a wrong conversion code')
    return res 

cv_type = 'FC'
temp = 212
print(f'{temp} Fahrenheit = {temp_conversion(cv_type,temp)} Celsius ')

#-+-+-+-+-+-+-+-+-
# Simulated deck of cards 
import random

suits = ['Clubs', 'Spades', 'Diamonds', 'Hearts']
num_cards = range(2,11)
face_cards = ['Jack', 'Queen', 'King', 'Ace']
cards = list(num_cards) + face_cards

deck = []
for i in suits:
    for card in cards:
        deck.append(f'{card} of {i}') #Append a list of a string and variables
print(f'This is the deck: \n{deck}')
print ()

card1 = random.choice(deck)
card2 = random.choice(deck)
print (f'You dealt 2 cards: \n1. {card1} \n2. {card2}')
print ()

#Shuffle my cards
random.shuffle(deck)

print(f'This is the deck shuffled: \n{deck}')
print ()
help(random.shuffle)

# deck of cards using dictionary

import random

suits = ['Clubs', 'Spades', 'Diamonds', 'Hearts']

num_cards = range(2,11)
face_cards = ['Jack', 'Queen', 'King','Ace']

cards = list(num_cards) + face_cards
deck = []

#method 2 - Creating the list through List Comprehensive
card_value = [x if isinstance(x,int) else (1,11) if x == 'Ace' else 10 for x in cards]

deck = {}
for i in suits:
    for j,card in enumerate(cards):
        deck[f'{card} of {i}'] = card_value[j]
print(f"Deck and it's value: \n {deck end =','}")



#-+-+-+-+-+-+-+-+-
# Perfect Numbers: if you add up all the factors of a number excluding the number it adds up to the number 
factors_x = []
x_low = 5
x_high = 500
def factor (x_low,x_high):
    for x in range (x_low,x_high):
        factors_x = [i for i in range(1, x + 1) if x % i == 0] 
        if sum(factors_x[:-1]) == factors_x[-1]:
            print(f'The addition of {factors_x[:-1]} = {sum(factors_x[:-1])} ')
            print(f'{factors_x[-1]} is a perfect number.')
        
factor (x_low,x_high)

perfect_nums = [x for x in range(2,500) if sum(factors(x)) == x]
print(perfect_nums)


#-+-+-+-+-+-+-+-+-

def fitbuzz():
    fizzbuzzList = ['fizzbuzz' if (i % 3 == 0 and i % 5 == 0) else 'fizz' if i % 3 == 0 else 'buzz' if i % 5 == 0 else i for i in range(1,31)]
    return fizzbuzzList

print (fitbuzz())
#-+-+-+-+-+-+-+-+-

def calc_Fibo (seq, total_iter):
    for i in range (total_iter):
        new_dig = seq[-2] + seq [-1]
        seq += [new_dig]
    return (seq)

print (f'The Fibonacci sequence to the 15th number: \n {calc_Fibo ([0,1],15)}')

#-+-+-+-+-+-+-+-+-
# Lucas sequence
def calc_Fibo (seq, total_iter):
    for i in range (total_iter):
        new_dig = seq[-2] + seq [-1]
        seq += [new_dig]
    return (seq)

print (f'The Lucas sequence to the 15th number: \n {calc_Fibo ([2,1],15)}')
print ()
golden_radio = calc_Fibo ([2,1],15)
print (f'The golden radio: {golden_radio[-1]/golden_radio[-2]}')
#-+-+-+-+-+-+-+-+-
# Longest list of composite numbers from 1000,3000
def is_prime(num):
    prime = False
    if num > 1:
        prime = True
        for i in range(2,num):
            if num % i == 0:
                prime = False
                break
    return prime

composites = []
longest_comp = []
for j in range(1000,3001):
    if is_prime(j):
        # reset
        if len(composites) >= len(longest_comp):
            longest_comp = composites
        print(f'Reset a prime was found {j}')
        composites = []
    else:
        composites.append(j)
        print(composites)
print('*'*35)
print(f'The length of the longest list of composites between 1000 and 3000 is {len(longest_comp)}')
print(longest_comp)


#-+-+-+-+-+-+-+-+-
# 1. Exercise - Even number. 
# numbers from 1000 to 3000 that are even numbers and when you add the digits the sum is divisible by 5 <br>
for i in range(1000, 3001):
    if i % 2 == 0:
        sum_str = sum([int(x) for x in str(i)])
        if sum_str % 5 == 0:
            print(i, str(i), sum_str)
#-+-+-+-+-+-+-+-+-
# sum up their ascii values
words = ['Love','Python','Dictionary','List','Tuple','Set','Ternary']
list_words = []
for i in words:
    add = 0 
    for y in i:
        add = add + ord(y)
    print (f"'{i}' its ascii value is: {add}'")
    list_words.append((i,add))
print (list_words)

#-+-+-+-+-+-+-+-+-







#-+-+-+-+-+-+-+-+-
#-+-+-+-+-+-+-+-+-
#-+-+-+-+-+-+-+-+-
#-+-+-+-+-+-+-+-+-

# %% [markdown]
# # SQL

# %%
import sqlite3
import os

os.chdir(r'...')
conn = sqlite3.connect('___.db') # create or use the Database
c = conn.cursor()
c.execute('''
    CREATE TABLE IF NOT EXISTS ______ (
    a_name TEXT,
    a_number INTEGER,
    ...
    )
''')
conn.commit()

c.execute('''
    CREATE TABLE IF NOT EXISTS country (
    country_name TEXT,
    population INTEGER,
    country_order INTEGER
    )
''')

with open('ABC_CORP_DATA.csv','r') as myFile:

    # 1 - Add the data to a data structure
    headLine = myFile.readline()
    content = myFile.readlines()
    for presd in (content):
            # Clean the data
            line_elements = presd.split(',')
            c.execute('''INSERT INTO employees
                    VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)''',line_elements[:13])
            conn.commit()

# %% [markdown]
# # SQL

# %%
import sqlite3
import os

cwd = os.getcwd()
print(cwd)
os.chdir(r'...')
conn = sqlite3.connect('____.db')  # <== create the database
cwd = os.getcwd()
c = conn.cursor()

#Create a several TABLES
c.executescript('''
    create table IF NOT EXISTS _____-table name- (
        colum_name1 TEXT,
        colum_name2 INTEGER
    );
    DELETE FROM _____-table name-;

    create table IF NOT EXISTS book(
        title TEXT,
        author TEXT,
        published TEXT,
        sale_date TEXT,
    );
    DELETE FROM book;

    INSERT INTO book (title, author, published) 
    VALUES ('Dirk Agency', 'Doublas Adam', 1987, '2020/11/20');
    ''')

conn.commit()

# INSERT DATA manually
c.execute("""INSERT into books(title, author, published) values ('001','Outliers','Malcolm Gladwell');""")
conn.commit()

# SHOW CONTENT in table 
c.execute('SELECT * FROM book')
r = c.fetchone()
for book in r:
    print(book)

# list all of the tables
c.execute("""SELECT name FROM sqlite_master""")
tables = c.fetchall()
for table in tables:
    print(table)


# DELETE a Table - Verify if the table is in library
for table in tables:
    print(table)
    if table[0] == 'book':
        c.execute('DROP TABLE book')
        print (f'Deleted {table[0]}')
        conn.commit()

#count all the values in book
c.execute('SELECT ALL count(*) FROM books') 
books = c.fetchall()

#Rename it back to books
c.execute('ALTER TABLE my_books RENAME TO books')
conn.commit()

#Rename a collumn
c.execute('ALTER TABLE books RENAME COLUMN title TO sub_title') #count all the values in book
conn.commit()

# Add column to a table 
c.execute('ALTER TABLE books ADD COLUMN price TEXT')
conn.commit()

# Set the price of all Blumnethal books at 9.99
c.execute(''' 
    UPDATE books SET
    price = '12.99' 
    WHERE author = 'Malcolm Gladwell' 
''') #WHERE author LIKE "%Blumenthal
conn.commit()

# MIN, MAX, CAST
c.execute('''SELECT MIN(CAST(price as REAL)) FROM books ORDER BY price DESC''')
books = c.fetchall()

c.execute('''SELECT MAX(Likes) FROM books''')
books = c.fetchall()

# SUM() and AVG()
c.execute('''SELECT AVG(CAST(price as REAL)) FROM books''')
books = c.fetchall()

c.execute('''SELECT SUM(CAST(price as REAL)) FROM books''')
books = c.fetchall()

#WHEN THEN
c.execute('''SELECT DISTINCT CASE marital_status
    WHEN 'Married' THEN 'M'
    WHEN 'Divorced' THEN 'D'
    else 'X' END code, marital_status FROM allData''')
rows = c.fetchall()


# HAVING
c.execute('SELECT marital_status, count(*) as tot FROM allData GROUP BY marital_status HAVING tot > 10')
tables = c.fetchall()

c.execute('''SELECT B.last_name, B.first_name, A.emp_id, sum(A.sale_amount) FROM sales A LEFT JOIN employees B on A.emp_id = B.emp_id GROUP BY A.emp_id HAVING sum(A.sale_amount) > 200000''')
tables = c.fetchall()

# JOIN and LIMIT explanation 
c.execute('''SELECT A.last_name, A.first_name, A.dept_id, B.id, B.description 
FROM employees as A LEFT JOIN depts B on A.dept_id = B.id 
ORDER BY A.last_name, A.first_name ASC 
LIMIT 5''')
names = c.fetchall()

c.execute('''SELECT A.last_name, A.first_name, A.manager_id, B.last_name, B.first_name 
FROM employees as A LEFT JOIN employees B on A.manager_id = B.emp_id 
ORDER BY A.manager_id, B.last_name, B.first_name ASC''')
names = c.fetchall()

c.execute('''SELECT A.first_name,A.last_name,A.emp_id,B.sale_amount,A.dept_id,C.description 
FROM allData A 
LEFT JOIN sales B  ON A.emp_id = B.emp_id 
LEFT JOIN depts C  ON A.dept_id = C.code 
WHERE A.dept_id = 'CSALE' and B.sale_amount > 0
''')
tables = c.fetchall()

# Who sold over 100,000
c.execute('''SELECT B.first_name,B.last_name,A.emp_id,sum(A.sale_amount) FROM sales A
LEFT JOIN allData B ON A.emp_id = B.emp_id GROUP BY A.emp_id HAVING sum(A.sale_amount) >100000 ''')
tables = c.fetchall()
# list all sales people with SALES > 1000
curr2.execute('''
SELECT X.last_name,X.first_name FROM allData X WHERE emp_id in 
(SELECT DISTINCT A.emp_id
FROM allData A 
LEFT JOIN sales B ON a.emp_id = B.emp_id
WHERE A.dept_id = 'CSALE' and B.sale_amount > 1000)
''')
tables = curr2.fetchall()


# UNION / UNION ALL (Join w repetitions)
c.execute('''SELECT last_name, first_name, ms_id FROM employees WHERE ms_id = "D" 
            UNION ALL
            SELECT last_name, first_name, ms_id FROM employees WHERE ms_id = "W" ''')
names = c.fetchall()

c.execute('''SELECT last_name, first_name, ms_id FROM employees WHERE ms_id = "D" 
            UNION
            SELECT last_name, first_name, ms_id FROM employees WHERE ms_id = "W" ''')
names = c.fetchall()

# WHERE
c.execute('SELECT emp_id, first_name, last_name, sick_days_alloted, sick_day1, sick_day2, sick_day3 FROM employees WHERE sick_day1 LIKE "%/%"')
names = c.fetchall()

c.execute('''SELECT code, state_name 
FROM states 
WHERE state_name LIKE "%North%" or state_name LIKE "%South%" or state_name LIKE "%West%"  or state_name LIKE "%East%"
;''') 
tables = c.fetchall()

c.execute('SELECT * FROM states WHERE state_name = "North" WHERE state_name = "South" WHERE state_name = "West" WHERE state_name = "East"')
tables = c.fetchall()

#Count distint values based on a field name
c.execute('SELECT count(DISTINCT title) FROM books') #count all the values in book
books = c.fetchall()

# COUNT of the employees by gender
c.execute('SELECT gender, count(1) FROM employees GROUP BY gender')
names = c.fetchall()
print ('Employees by gender:')
print (f'  -  There are {names[0][1]} women and {names[1][1]} men.')
conn.close()







# !!! REVIEW Day 11 - Having, Count of emplyees by gender


# conn.close()

# %%
# .txt .csv
# Kelvin txt 'r' - while / clean / insert

country_data = {}
with open('Country_pops.csv','r') as fh:
    line = fh.readline()
    line_cntr = 0
    while line:
        # skip the header
        if line_cntr > 1:
            name, *population = line.split(',')
            population = \
            (''.join([x.strip('\n') for x in population])).replace('"','').replace('-','')
            country_data[name] = int(population)
            print(name, population)
            pop_data = (name, population)
            c.execute('INSERT INTO country (country_name, population) VALUES (?,?)',pop_data)
        line_cntr += 1
        line = fh.readline()
# print(country_data)
sorted_pop = sorted(country_data.items(), key = lambda kv: kv[1], reverse = True)
print(sorted_pop)
conn.close()

# %% [markdown]
# ## MYSQL

# %% [markdown]
# <h2>MYSQL Data Types</h2>
# CHAR<br>
# VARCHAR<br>
# INT<br>
# INTEGER<br>
# FLOAT<br>
# DOUBLE<br>
# DECIMAL(10.2)<br>
# DATE<br>
# DATETIME<br>
# TIMESTAMP<br>

# %%
import os
import mysql.connector

os.chdir(r' ... ')

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}
conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('CREATE DATABASE IF NOT EXISTS ABC_CORP;')  # <------ The database
conn.commit()
curr.execute('USE ABC_CORP;')  # <------ The database
sql = 'CREATE TABLE IF NOT EXISTS states (code CHAR(2),state_name VARCHAR(50))'
curr.execute(sql)
conn.commit()
sql = 'DELETE FROM states;'
curr.execute(sql)
conn.commit()


with open(r'c:\projects\US_states_codes.txt') as fh:
    line = fh.readline()
    while line:
        state_name,code = line.split('-')
        state_name = state_name.strip()
        code = code.strip().replace('\n','')
        print(code,state_name)
        sql = f'''INSERT INTO states VALUES ('{code}','{state_name}') '''
        # print(sql)
        curr.execute(sql)
        conn.commit()
        line = fh.readline()
        
curr.execute('SELECT code, state_name, length(state_name) FROM states ORDER BY state_name;')  # <------ The database
tables = curr.fetchall()
for table in tables:
    print(table)        
conn.close()

curr.execute('''SELECT code, state_name 
FROM states 
WHERE state_name IN ('Rhode Island','Maine','New Hampshire')
;''') 
tables = curr.fetchall()

# %% [markdown]
# # Dictionary

# %%
# =========================
# Take the following phrases iterate over them and return the top 5 letters found

phrases = [['How much wood could a wood chuck chuck if a woodchuck could chuck wood'],
           ['Sally sells sea shells by the sea shore']]
letters = {}
for i in phrases[0]:
    for y,x in enumerate (i):
        x.lower() 
        if not x in letters:
            letters [x] = 0 
        letters [x] += 1 
print (letters)

# =========================

grocery_list = {'2021-1-3':{'milk': 4.99},
                '2021-1-10':{'milk': 4.99,'eggs': 6.99, 'beer': 14.99},
                '2021-2-1':{'Broccoli': 2.99,'Onions': 1.99, 'peppers': 3.69},
                '2021-2-6':{'milk': 4.99,'eggs': 6.99, 'beer': 19.99},
                '2021-3-5':{'Coffee': 6.19,'eggs': 6.99, 'beer': 18.99},
                '2021-3-20':{'Flour': 4.19,'Beer': 17.99, 'Diapers': 12.99},
                '2021-4-1':{'milk': 5.29,'eggs': 7.59,'Flour': 4.39}}

# 1. What was the total grocery bill for each month
tot_month = {}
for dates,vals in grocery_list.items():
    y,m,d = dates.split('-')
    if not m in tot_month:
        tot_month[m] = 0
    tot_month[m] += sum([v2 for k2,v2 in vals.items()])
print (tot_month)

# 2 - What was the average price paid for each commodity (remove misspellings) 
per_item = {}
for dates,vals in grocery_list.items():
    for comodity,price in vals.items():
        # print (comodity)
        comodity = comodity.title()
        if not comodity in per_item:
            per_item[comodity] = []
        per_item[comodity].append(price)
print (per_item)
print()
avg_cost = [(k,round(sum(v)/len(v),2) if len(v) else None) for k,v in per_item.items()]
print (avg_cost)


# 3 - Create a dictionary with the item name as key and the value a tuple with
# (the number of times item purchased,Total spent across all months)
# In [ ]:

per_item = {}
for dates,vals in grocery_list.items():
    for comodity,price in vals.items():
        # print (comodity)
        comodity = comodity.title()
        if not comodity in per_item:
            per_item[comodity] = []
        per_item[comodity].append(price)
print (per_item)
print()

avg_cost = {k: (len(v),round(sum(v),2)) for k,v in per_item.items()}
print (avg_cost)



# =========================
# 1 - Calculate the mean, median for each individual Quiz
grades = {'100': {'Quiz-1': 80, 'Quiz-2': 92, 'Quiz-3': 84},
         '101': {'Quiz-1': 93, 'Quiz-2': 95, 'Quiz-3': 90},
         '102': {'Quiz-1': 88, 'Quiz-2': 94, 'Quiz-3': 88},
         '103': {'Quiz-1': 88, 'Quiz-2': 97, 'Quiz-3': 93},
         '104': {'Quiz-1': 85, 'Quiz-2': 92, 'Quiz-3': 90}}

students = {'101': ['Morgan','Debra'],
           '100': ['Palmer','Sara'],
           '102': ['Delgado','Luis'],
           '104': ['Cruz','Maria'],
           '103': ['Korencho','Victor']}

def calc_mean(lst):
    return sum(lst)/len(lst) if len(lst) > 0 else None
quiz_scores = {}
for k,v in grades.items():
    for i in range(1,4):
        print(i,v.get(f'Quiz-{i}'))
        if not i in quiz_scores:
            quiz_scores[i] = []
        quiz_scores[i].append(v.get(f'Quiz-{i}'))
print(quiz_scores)
for quiz_no,values in quiz_scores.items():
    print(f'The mean for quiz {quiz_no} is {calc_mean(values)}')

# 2 - Calculate the mean for each student:

def calc_mean(lst):
    return sum(lst)/len(lst) if len(lst) > 0 else None
def calc_median(lst):
    lst.sort()
    # print(lst)
    if len(lst) % 2 == 0:
        # even number
        middle_val = int(len(lst)/2)
        median = (lst[middle_val-1] + lst[middle_val])/2
    else:
        # odd number - take the middle number
        median = lst[int((len(lst)-1)/2)]
    return median

print(calc_median([80,70,85,90]))
quiz_scores = {}
for k,v in grades.items():
    for i in range(1,4):
        print(i,v.get(f'Quiz-{i}'))
        if not i in quiz_scores:
            quiz_scores[i] = []
        quiz_scores[i].append(v.get(f'Quiz-{i}'))
print(quiz_scores)
for quiz_no,values in quiz_scores.items():
    print(f'The mean for quiz {quiz_no} is {calc_mean(values)}')
    print(f'The median for quiz {quiz_no} is {calc_median(values)}')
print('*'*35)
for k,v in grades.items():
    sum_g = 0
    s_grades = []
    for k2,v2 in v.items():
        s_grades.append(v2)
    print(k,students[k][0],students[k][1][:1],calc_mean(s_grades))
    print('='*35)

# =========================

purchases = {'2021-01-01': 
                 {'item-001': 
                      {'name': 'Alka Seltzer'},
                 'item-002': 
                      {'name': 'Rolaids'},
                 'item-003': 
                      {'name': 'Orange juice'}}
             }
                
print(type(purchases))    
if isinstance(purchases,dict):
    print(f'I found a dictionary {purchases}')
print('='*35)
# Step 1 - iterate
for k,v in purchases.items():
     #print(k, v)        # k is the date, v is the values, which is another dictionary
     #print(type(v),v)   # type of v is a dictionary
     for k2,v2 in v.items():  # In this way to iterate inside of v dictionary k2 are the keys ('item-001-3')
          #print(v2)      # v2 are the values, within a dictionary too. 
          #print(type(v2), v2) # v2 is a dictionary too. 
          for k3, v3 in v2.items(): # This is the 3rd itaration ober the dictionary. To get the values:
               print(f'You bought {v3}')

# =========================

countries = []
for k,v in np.items():
    for i in v:
        if len(i) > 1:
            country = i['name'], i['code']
        else:
            country = i['name'], 'NA' 
        countries.append(country) 

print (f'This is the list of tuple: {tuple (countries)}')

#Kelvin solution
countries = []
for K,v in np.items():
    print (K, type(v))
    for values in v:
        country = values.get('name')
        code = values.get('code')
        doce = code if code else 'N/A'
        # print(code, country)
        x = (code, country)
        countries.append(x)

print (countries)
print(f'The total number of countries is {len(countries)}')

# %%
try:

except:
    pass
