# %% [markdown]
# # MySQL

# %%
import os
import mysql.connector


mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('CREATE DATABASE IF NOT EXISTS Analytics;')  # <------ The database
conn.commit()
curr.execute('USE Analytics;')  # <------ The database
sql = '''CREATE TABLE IF NOT EXISTS stock_price 
        (symbol VARCHAR(10), 
        trade_date DATE, 
        open_price DOUBLE, 
        high_price DOUBLE, 
        low_price DOUBLE, 
        close_price DOUBLE, 
        adj_close_price DOUBLE, 
        volume INT);'''
curr.execute(sql)
conn.commit()
curr.execute('truncate table stock_price;')
conn.commit()
# sql = 'DELETE FROM states;'
# curr.execute(sql)
# conn.commit()

os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Reinforment class')
with open('INTC.csv', 'r') as f:
    headline = f.readline()
    lines = f.readlines()
    print (headline)
    # print (lines[0])
    symbol = 'INTC'
    for i in lines:
        list_data =  i.replace('\n', '').split(',')
        # print (list_data, type(list_data[0]), type(list_data[1]), type(list_data[2]), type(list_data[3]))
        date_op, open_value, high_value, low_value, close_value, adj_close, volume = list_data[0], float(list_data[1]), float(list_data[2]), float(list_data[3]), float(list_data[4]), float(list_data[5]), int(list_data[6])  
        sql = f'''INSERT INTO stock_price (symbol, trade_date, close_price, volume) 
        VALUES
        ('{symbol}','{date_op}','{close_value}','{volume}')
        '''
        curr.execute(sql)
        conn.commit()
        # print(sql)
conn.close()

# %%
# Show the info in the table stock_price

import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')  # <------ The database
curr.execute('SELECT * FROM stock_price') 
tables = curr.fetchall()
# print(len(tables))
for table in tables:
    print(table[0],table[1],table[5],table[7],len(table))  
conn.close()

# %%
#COUNT how many item w 'INTC'

import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')  # <------ The database
curr.execute('SELECT count(*) FROM stock_price WHERE symbol like "INTC"') 
tables = curr.fetchall()
# print(tables)
for table in tables:
    print(table[0],table[1],table[5],table[7],len(table))  
conn.close()

# %%
# Put in date order by date

import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')  # <------ The database
curr.execute('SELECT * FROM stock_price ORDER BY trade_date DESC') 
tables = curr.fetchall()
# print(tables)
for table in tables:
    print(table[1])  
conn.close()

# %% [markdown]
# # Exercise
# 1 - What was the average stock price? <br>
# 2 - Max stock price?<br>
# 3 - What day was the max stock price achieved?<br>
# 4 - Lowest stock price?<br>
# 5 - What day was the lowest stock price achieved?<br>
# 6 - What was the average volume traded?<br>
# 7 - Max volume?<br>
# 8 - What day was the max volume achieved?<br>
# 9 - Lowest volume traded?<br>
# 10 - What day was the lowest volume achieved?<br>

# %%
import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

max_price_day = None
min_price_day = None
last_price = None
first_price = None
conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')  # <------ The database

# ---------------------------------- 
# 1 - What was the average stock price 

curr.execute('SELECT avg(close_price) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    print(f'1. The avarage stock price is {round(row[0],2)}')

# ----------------------------------
# 2 - Max stock price
curr.execute('SELECT MAX(close_price) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    print(f'2. The max stock price is {round(row[0],2)}')

# ----------------------------------
# 3 - What day was the max stock price achieved
curr.execute('SELECT * FROM stock_price ORDER BY close_price DESC LIMIT 1')
rows = curr.fetchall()
max_price_day = type(rows[0][0])
for row in rows:
    print(f'3 - The date the maximum stock price was acheived was {row[1]} - ${row[5]}')
    max_price_day = row[1]
    last_price = row[5]
    # print (max_price_day, last_price)
conn.close()

# %%
import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')

# ----------------------------------
# 4 - Lowest stock price
curr.execute('SELECT MIN(close_price) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    print(f'4. The lowest stock price is {row[0]}')

# ----------------------------------
# 5 - What day was the lowest stock price achieved

curr.execute('SELECT * FROM stock_price ORDER BY close_price ASC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'5. The date in which the lowest stock price was achieved {row[1]} - ${row[5]}')
    min_price_day = row[1]
    first_price = row[5]
# print (max_price_day, last_price)

# ----------------------------------
# 6 - What was the average volume traded
curr.execute('SELECT avg(volume) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    avg_vol = round(row[0])
    print(f'6. The average volume traded {round(row[0])}')
conn.close()

# %%
import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')

# ----------------------------------
# 7 - Max volume
curr.execute('SELECT MAX(volume) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    print(f'7. The max volume is {round(row[0],2)}')

# ----------------------------------
# 8 - What day was the max volume achieved
curr.execute('SELECT trade_date FROM stock_price ORDER BY volume DESC LIMIT 1') 
rows = curr.fetchall()
for row in rows:
    print(f'8. The day the max volume achieved was {row[0]}')

# ----------------------------------
# 9 - Lowest volume traded
curr.execute('SELECT MIN(volume) FROM stock_price') 
rows = curr.fetchall()
for row in rows:
    print(f'9. The lowest volume traded is {round(row[0],2)}')

# ----------------------------------
# 10 - What day was the lowest volume achieved
curr.execute('SELECT trade_date FROM stock_price ORDER BY volume ASC LIMIT 1') 
rows = curr.fetchall()
for row in rows:
    print(f'10. The day when the lowest volume achieved was {row[0]}')


conn.close()

# %% [markdown]
# # Exercise
# How many days between the lowest price and the highest price? <br>
# What was the rate of return for this security?<br>
# (last_price - first_price)/first_price for example<br>
# day 1 stock price 100<br>
# day 5 stock price is 110<br>
# To calculate the ROR<br>
# (110 - 100)/100 = 10/100 = 1/10 = .1 * 100 = 10%<br>

# %%
import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')


# max_price_day, min_price_day coming from Q3 y Q5
if max_price_day and min_price_day:
    print (max_price_day, min_price_day)
    days_between = max_price_day - min_price_day
    print(type(days_between), days_between)
    days_between = (max_price_day - min_price_day).days
    print(f'It took {days_between} days to go from the lowest price to the highest')
# (last_price - first_price)/first_price 
if first_price and last_price:
    print (first_price, last_price)
    ror = ((last_price - first_price)/first_price)*100
    print(f'The rate of return was {round(ror,2)}')
conn.close()

# %%
import os
import mysql.connector

mysql_config =  {
  'user': 'root',
  'password': 'Admin321',
  'host': '127.0.0.1',
  'auth_plugin':'mysql_native_password'
}

conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('USE Analytics')


curr.execute('SELECT AVG(volume) FROM stock_price')
rows = curr.fetchall()
# avg_vol comes from Q6
curr.execute(f'SELECT * FROM stock_price WHERE volume > {avg_vol}')
rows = curr.fetchall()
for row in rows:
  print(row[1], row[5], row[7])

# %% [markdown]
# # Slite

# %%
import sqlite3
import os

os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Reinforment class')

conn = sqlite3.connect('Analytics.db')  # <== create the database
c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS stock_price 
        (symbol TEXT, 
        trade_date DATE, 
        open_price FLOAT, 
        high_price FLOAT, 
        low_price FLOAT, 
        close_price FLOAT, 
        adj_close_price FLOAT, 
        volume INTeger)''')
conn.commit()
c.execute('DELETE FROM stock_price')
conn.commit()

print('='*40)
c.execute('''SELECT name FROM sqlite_master''')
tables = c.fetchall()
for table in tables:
    print(table)

with open('INTC.csv', 'r') as f:
    headline = f.readline()
    lines = f.readlines()
    # print (headline)
    # print (lines[0])
    symbol = 'INTC'
    print('='*40)
    for i in lines:
        list_data =  i.replace('\n', '').split(',')
        # print (list_data, type(list_data[0]), type(list_data[1]), type(list_data[2]), type(list_data[3]))
        date_op, open_value, high_value, low_value, close_value, adj_close, volume = list_data[0], float(list_data[1]), float(list_data[2]), float(list_data[3]), float(list_data[4]), float(list_data[5]), int(list_data[6])  
        print (f'{symbol}, {date_op}, {close_value}, {volume}')
        c.execute(f"""INSERT INTO stock_price (symbol, trade_date, close_price, volume) VALUES ('{symbol}', '{date_op}', {close_value}, {volume})""")
        conn.commit()

# %%
import sqlite3
import os

os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Reinforment class')

conn = sqlite3.connect('Analytics.db')  # <== create the database
curr = conn.cursor()
max_price_day = None
min_price_day = None
first_price = None
last_price = None
# --------------------------------
curr.execute('SELECT AVG(close_price) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q1 - The average stock price is {round(row[0],2)}')
# ------------------------------------
curr.execute('SELECT MAX(close_price) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q2 - The maximum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,close_price FROM stock_price ORDER BY close_price DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q3 - The date the maximum stock price was acheived was {row[0]}')
    max_price_day = row[0]
    last_price = row[1]
# ------------------------------------
curr.execute('SELECT MIN(close_price) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q4 - The minimum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('''SELECT trade_date,close_price 
FROM stock_price 
ORDER BY close_price ASC LIMIT 1''')
rows = curr.fetchall()
for row in rows:
    print(f'Q5 - The date the minimum stock price was acheived was {row[0]}')
    min_price_day = row[0]
    first_price = row[1]
# ------------------------------------
curr.execute('SELECT AVG(volume) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q6 - The average volume was {round(row[0])}')
# ------------------------------------
curr.execute('SELECT MAX(volume) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q7 - The maximum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_price ORDER BY volume DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q8 - The date the maximum volume was acheived was {row[0]}')
    # print(row)
# ------------------------------------
curr.execute('SELECT MIN(volume) FROM stock_price')
rows = curr.fetchall()
for row in rows:
    print(f'Q9 - The minimum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_price ORDER BY volume ASC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q10 - The date the minimum volume was acheived was {row[0]}')

# %% [markdown]
# # Exercise
# How many days between the lowest price and the highest price? <br>
# What was the rate of return for this security?<br>
# (last_price - first_price)/first_price for example<br>
# day 1 stock price 100<br>
# day 5 stock price is 110<br>
# To calculate the ROR<br>
# (110 - 100)/100 = 10/100 = 1/10 = .1 * 100 = 10%<br>

# %%
import datetime 
if max_price_day and min_price_day:
    print (max_price_day, min_price_day)
    y1,m1,d1 = max_price_day.split('-')
    y2,m2,d2 = min_price_day.split('-')
    diff = (datetime.date(int(y1),int(m1),int(d1)) - \
            datetime.date(int(y2),int(m2),int(d2)) ).days
    print(max_price_day,type(max_price_day),min_price_day,type(min_price_day))
    print(f'It took {diff} days to go from the lowest price to the highest')
# (last_price - first_price)/first_price 
if first_price and last_price:
    ror = ((last_price - first_price)/first_price)*100
    print(f'The rate of return was {round(ror,2)}')
conn.close()
# Out:
# 2020-01-24 2019-06-03
# 2020-01-24 <class 'str'> 2019-06-03 <class 'str'>
# It took 235 days to go from the lowest price to the highest
# The rate of return was 57.55

# %% [markdown]
# # Exercise
# Print all of January 2021's trades

# %%
import sqlite3
import os

os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Reinforment class')

conn = sqlite3.connect('Analytics.db')  # <== create the database
curr = conn.cursor()
curr.execute("SELECT * FROM stock_price WHERE trade_date LIKE '2019-01-%'")
rows = curr.fetchall()
for row in rows:
    print (row)
# Out:
# ('INTC', '2019-01-22', None, None, None, 48.27, None, 25940700)
# ('INTC', '2019-01-23', None, None, None, 47.939999, None, 18960700)
# ('INTC', '2019-01-24', None, None, None, 49.759998, None, 50578300)
# ('INTC', '2019-01-25', None, None, None, 47.040001, None, 86455700)
# ('INTC', '2019-01-28', None, None, None, 46.709999, None, 35928700)
# ('INTC', '2019-01-29', None, None, None, 46.540001, None, 20988300)
# ('INTC', '2019-01-30', None, None, None, 47.540001, None, 26931700)
# ('INTC', '2019-01-31', None, None, None, 47.119999, None, 43051300)

# %%
import sqlite3
import os

os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Reinforment class')

conn = sqlite3.connect('Analytics.db')  # <== create the database
curr = conn.cursor()
moving_avg = []
curr.execute('SELECT * FROM stock_price')
rows = curr.fetchall()
for row in rows:
    if len(moving_avg) >= 5:
        moving_avg = moving_avg[-5:]
        print (moving_avg)
        print(row, moving_avg, sum(moving_avg)/len(moving_avg))
        # start moving avg
    moving_avg.append(row[1])
    # print(row)
# Out:
# ['2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pl/clj7x4m153j6y749_p0tpx4m0000gn/T/ipykernel_9072/635014085.py in <module>
#      13         moving_avg = moving_avg[-5:]
#      14         print (moving_avg)
# ---> 15         print(row, moving_avg, sum(moving_avg)/len(moving_avg))
#      16         # start moving avg
#      17     moving_avg.append(row[1])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Kelvin's code
import os
import mysql.connector
mysql_config =  {
  'user': 'root',
  'password': 'admin321',
  'host': '127.0.0.1'
}
conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
curr.execute('CREATE DATABASE IF NOT EXISTS Analytics;')  # <------ The database
conn.commit()
curr.execute('USE Analytics')
sql = '''CREATE TABLE IF NOT EXISTS stock_prices
(symbol VARCHAR(10),
trade_date DATE,
open_price DOUBLE,
high_price DOUBLE,
low_price DOUBLE,
close_price DOUBLE,
adj_close_price DOUBLE,
volume INT)'''
curr.execute(sql)
conn.commit()
curr.execute('truncate table stock_prices;')
conn.commit()
# sql = 'DELETE FROM states;'
# curr.execute(sql)
# conn.commit()
file_name = 'c:\\temp\\intc.csv'
with open(file_name,'r') as fh:
    line = fh.readline()
    cntr = 0
    while line:
        if cntr > 0:
            # print(line)
            stock_data = line.split(',')
            symbol = 'INTC'
            trade_date = stock_data[0]
            open_price = float(stock_data[1])
            high_price = float(stock_data[2])
            low_price = float(stock_data[3])
            close_price = float(stock_data[4])
            adj_close_price = float(stock_data[5])
            volume = int(stock_data[6].replace('\n',''))
            print(symbol,trade_date,open_price,high_price,low_price,\
                  close_price,adj_close_price,volume)
            sql = f'''INSERT INTO stock_prices
            (symbol,trade_date,close_price,volume)
            VALUES
            ('{symbol}','{trade_date}',{close_price},{volume})
            '''
            curr.execute(sql)
            conn.commit()
            print(sql)
        cntr += 1
        line = fh.readline()
conn.close()

# %%
import os
import mysql.connector
mysql_config =  {
  'user': 'root',
  'password': 'admin321',
  'host': '127.0.0.1'
}
max_price_day = None
min_price_day = None
first_price = None
last_price = None
conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
# curr.execute('CREATE DATABASE IF NOT EXISTS analytic2')
curr.execute('USE Analytics')
# --------------------------------
curr.execute('SELECT AVG(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q1 - The average stock price is {round(row[0],2)}')
# ------------------------------------
curr.execute('SELECT MAX(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q2 - The maximum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,close_price FROM stock_prices ORDER BY close_price DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q3 - The date the maximum stock price was acheived was {row[0]}')
    max_price_day = row[0]
    last_price = row[1]
# ------------------------------------
curr.execute('SELECT MIN(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q4 - The minimum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('''SELECT trade_date,close_price 
FROM stock_prices 
ORDER BY close_price ASC LIMIT 1''')
rows = curr.fetchall()
for row in rows:
    print(f'Q5 - The date the minimum stock price was acheived was {row[0]}')
    min_price_day = row[0]
    first_price = row[1]
    # print(row)
# ------------------------------------
curr.execute('SELECT AVG(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q6 - The average volume was {round(row[0])}')
    # print(row)  
# ------------------------------------
curr.execute('SELECT MAX(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q7 - The maximum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_prices ORDER BY volume DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q8 - The date the maximum volume was acheived was {row[0]}')
    # print(row)
# ------------------------------------
curr.execute('SELECT MIN(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q9 - The minimum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_prices ORDER BY volume ASC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q10 - The date the minimum volume was acheived was {row[0]}')

# EXERCISE 2

if max_price_day and min_price_day:
    days_between = max_price_day - min_price_day
    print(type(days_between))
    days_between = (max_price_day - min_price_day).days
    print(f'It took {days_between} days to go from the lowest price to the highest')
# (last_price - first_price)/first_price 
if first_price and last_price:
    ror = ((last_price - first_price)/first_price)*100
    print(f'The rate of return was {round(ror,2)}')
conn.close()

# %%
# EXECISE 3

import os
import mysql.connector
mysql_config =  {
  'user': 'root',
  'password': 'admin321',
  'host': '127.0.0.1'
}
max_price_day = None
min_price_day = None
first_price = None
last_price = None
conn = mysql.connector.connect(**mysql_config)
curr = conn.cursor(buffered=True)
# curr.execute('CREATE DATABASE IF NOT EXISTS analytic2')
curr.execute('USE Analytics')
# ------------------------------------
curr.execute('SELECT AVG(volume) FROM stock_prices')
rows = curr.fetchall()
avg_volume = None
for row in rows:
    avg_volume = round(row[0])
    print(f'Q6 - The average volume was {avg_volume}')
# ------------------------------------
sql = f'''SELECT trade_date,close_price,volume 
FROM stock_prices 
WHERE volume > {avg_volume}'''
print(sql)
curr.execute(sql)
rows = curr.fetchall()
for row in rows:
    print(row)

# %% [markdown]
# # k-Slite

# %%
import os
import sqlite3
filePath = 'C:\\Projects\\SQL_NOSQL\\'
os.chdir(filePath)
conn = sqlite3.connect("Analytics.db")
curr = conn.cursor()
print('='*40) 
sql = '''CREATE TABLE IF NOT EXISTS stock_prices 
(symbol TEXT, 
trade_date DATE,
open_price FLOAT,
high_price FLOAT,
low_price FLOAT,
close_price FLOAT,
adj_close_price FLOAT,
volume INTEGER)'''
curr.execute(sql)
conn.commit()
sql = 'DELETE FROM stock_prices'
curr.execute(sql)
conn.commit()
print('='*40)
curr.execute('''SELECT name FROM sqlite_master''')
tables = curr.fetchall()
for table in tables:
    print(table)
    
# load the data
file_name = 'c:\\temp\\intc.csv'
with open(file_name,'r') as fh:
    line = fh.readline()
    cntr = 0
    while line:
        if cntr > 0:
            # print(line)
            stock_data = line.split(',')
            symbol = 'INTC'
            trade_date = stock_data[0]
            open_price = float(stock_data[1])
            high_price = float(stock_data[2])
            low_price = float(stock_data[3])
            close_price = float(stock_data[4])
            adj_close_price = float(stock_data[5])
            volume = int(stock_data[6].replace('\n',''))
            curr.execute(f'''INSERT INTO stock_prices
            (symbol,trade_date,close_price,volume)
            VALUES ('{symbol}','{trade_date}',{close_price},{volume})''')
            conn.commit()            
            # print(sql)
        cntr += 1
        line = fh.readline()
conn.close()

# %%
import os
import sqlite3
filePath = 'C:\\Projects\\SQL_NOSQL\\'
os.chdir(filePath)
conn = sqlite3.connect("Analytics.db")
curr = conn.cursor()
# print('='*40) 
# sql = '''SELECT * FROM stock_prices'''
# curr.execute(sql)
# rows = curr.fetchall()
# for row in rows:
#     print(row)
max_price_day = None
min_price_day = None
first_price = None
last_price = None
# --------------------------------
curr.execute('SELECT AVG(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q1 - The average stock price is {round(row[0],2)}')
# ------------------------------------
curr.execute('SELECT MAX(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q2 - The maximum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,close_price FROM stock_prices ORDER BY close_price DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q3 - The date the maximum stock price was acheived was {row[0]}')
    max_price_day = row[0]
    last_price = row[1]
# ------------------------------------
curr.execute('SELECT MIN(close_price) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q4 - The minimum stock price is {round(row[0],2)}')   
# ------------------------------------
curr.execute('''SELECT trade_date,close_price 
FROM stock_prices 
ORDER BY close_price ASC LIMIT 1''')
rows = curr.fetchall()
for row in rows:
    print(f'Q5 - The date the minimum stock price was acheived was {row[0]}')
    min_price_day = row[0]
    first_price = row[1]
    # print(row)
# ------------------------------------
curr.execute('SELECT AVG(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q6 - The average volume was {round(row[0])}')
    # print(row)  
# ------------------------------------
curr.execute('SELECT MAX(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q7 - The maximum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_prices ORDER BY volume DESC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q8 - The date the maximum volume was acheived was {row[0]}')
    # print(row)
# ------------------------------------
curr.execute('SELECT MIN(volume) FROM stock_prices')
rows = curr.fetchall()
for row in rows:
    print(f'Q9 - The minimum volume is {round(row[0],2)}')   
# ------------------------------------
curr.execute('SELECT trade_date,volume FROM stock_prices ORDER BY volume ASC LIMIT 1')
rows = curr.fetchall()
for row in rows:
    print(f'Q10 - The date the minimum volume was acheived was {row[0]}')



if max_price_day and min_price_day:
    days_between = max_price_day - min_price_day
    print(type(days_between))
    days_between = (max_price_day - min_price_day).days
    print(f'It took {days_between} days to go from the lowest price to the highest')
# (last_price - first_price)/first_price 
if first_price and last_price:
    ror = ((last_price - first_price)/first_price)*100
    print(f'The rate of return was {round(ror,2)}')
conn.close()

# %%
if max_price_day and min_price_day:
    y1,m1,d1 = max_price_day.split('-')
    y2,m2,d2 = min_price_day.split('-')
    diff = (datetime.date(int(y1),int(m1),int(d1)) - \
            datetime.date(int(y2),int(m2),int(d2)) ).days
    print(max_price_day,type(max_price_day),min_price_day,type(min_price_day))
    print(f'It took {diff} days to go from the lowest price to the highest')
# (last_price - first_price)/first_price 
if first_price and last_price:
    ror = ((last_price - first_price)/first_price)*100
    print(f'The rate of return was {round(ror,2)}')
conn.close()
