# %%
import sqlite3
help(sqlite3)
# Out:
# Help on package sqlite3:
#
# NAME
#     sqlite3
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/sqlite3
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     # pysqlite2/__init__.py: the pysqlite2 package.
#     #
#     # Copyright (C) 2005 Gerhard Häring <gh@ghaering.de>
#     #
#     # This file is part of pysqlite.
#     #
#     # This software is provided 'as-is', without any express or implied
#     # warranty.  In no event will the authors be held liable for any damages
#     # arising from the use of this software.
#     #
#     # Permission is granted to anyone to use this software for any purpose,
# ...

# %%
import os

cwd = os.getcwd()
print(cwd)
os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature')
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature

# %% [markdown]
# #### Let's create a directory to store all of our jupyter notebooks for this course
# #### Create a dirctory called 'Project\SQL_NOSQL

# %%
import os

cwd = os.getcwd()
print(cwd)
os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature')
cwd = os.getcwd()
print(cwd)
os.mkdir(r'Project_SQL_NOSQL')
# Out:
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature

# %%
os.chdir(r'/Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature')
print(os.getcwd())
# Out:
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature

# %% [markdown]
# <h2>Let's determine which directory we are in</h2>

# %%
print(os.getcwd())
# Out:
# /Users/julis_478/Documents/Python Immersives/PY-112 SQL, No SQL/Classes/Activities Github/Day3_SQL-Lesson01:Temperature

# %% [markdown]
# <h2>Create a database and establish a connection to it</h2>

# %%
import sqlite3

conn = sqlite3.connect('customer.db')

# %% [markdown]
# <h2>If we attempt to connect to a database that does not exist.  It creates it.</h4>

# %% [markdown]
# <h2>Let's examine the methods available for the object we just created</h2>
# ```
# [x for x in dir(conn) if not x.startswith('_')]
# ```

# %%
print([x for x in dir(conn) if not x.startswith('_')])
# Out:
# ['DataError', 'DatabaseError', 'Error', 'IntegrityError', 'InterfaceError', 'InternalError', 'NotSupportedError', 'OperationalError', 'ProgrammingError', 'Warning', 'backup', 'close', 'commit', 'create_aggregate', 'create_collation', 'create_function', 'cursor', 'execute', 'executemany', 'executescript', 'in_transaction', 'interrupt', 'isolation_level', 'iterdump', 'rollback', 'row_factory', 'set_authorizer', 'set_progress_handler', 'set_trace_callback', 'text_factory', 'total_changes']

# %%
import glob

for i in glob.glob('*.db'):
    print(i)
# Out:
# customer.db

# %% [markdown]
# <h2>A database holds zero or more tables</h2>

# %%
# Create a cursor to access the database
c = conn.cursor()
# This is equivalent to creating a filehandle when using the 'open' function
dir(c)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'arraysize',
#  'close',
#  'connection',
#  'description',
#  'execute',
#  'executemany',
#  'executescript',
#  'fetchall',
#  'fetchmany',
#  'fetchone',
#  'lastrowid',
#  'row_factory',
#  'rowcount',
#  'setinputsizes',
#  'setoutputsize']

# %%
c.execute('''CREATE TABLE customers (
    first_name TEXT,
    last_name TEXT,
    address1 TEXT,
    address2 TEXT,
    city TEXT,
    state TEXT,
    zip TEXT
)''')
conn.commit() # <=== commit our table changes to the database !!!
conn.close()  # Close the connection
'''
WARNING !!!! If the table was created already it is going to give you an error
'''
# Out:
# '\nWARNING !!!! If the table was created already it is going to give you an error\n'

# %%
conn = sqlite3.connect('customer.db')
c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS customers (
    first_name TEXT,
    last_name TEXT,
    address1 TEXT,
    address2 TEXT,
    city TEXT,
    state TEXT,
    zip TEXT
)''')
conn.commit() # <=== commit our table changes to the database !!!
conn.close()  # Close the connection

# %% [markdown]
# <h2>How can we view the tables already created<br> in
# a database?<h2>

# %%
'''
There are several tools we can use to view our SQLite database and the tables outside of python
1. Install full version of SQLite3 - www.sqlite.org
2. Install a browser add in - SQLite Manager by Lunu ( PREFERRED)

Examine the customer.db file we created
Examine the chinook.db file 

Look at the syntax

'''
conn = sqlite3.connect('customer.db')
c = conn.cursor()
for row in c.execute("""SELECT name FROM sqlite_master"""):
    print(row)
conn.commit()  # <=== commit our table to the database
conn.close()
# Out:
# ('customers',)

# %% [markdown]
# <h2>CRUD operations - UPDATE</h2>

# %%
'''
    first_name TEXT,
    last_name TEXT,
    address1 TEXT,
    address2 TEXT,
    city TEXT,
    state TEXT,
    zip TEXT
'''
conn = sqlite3.connect('customer.db')
c = conn.cursor()
c.execute('''INSERT INTO customers VALUES
('Mary','Jones','1 Park Avenue','Apt 2a','Brooklyn','NY','11234')''')
conn.commit()  # <=== commit our table to the database
conn.close()
